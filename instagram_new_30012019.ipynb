# %% [markdown]
# <a href="https://colab.research.google.com/github/joker2017/Calculator/blob/master/instagram_new_30012019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import json
import re
import requests



session = requests.Session()

      
def update(obj=None, settings={}):
        
        
        query = "https://www.instagram.com/"
        if not obj is None:
            query += base_url + primary_key
        
        response = session.get(query, **settings)
        match = re.search(r"<script[^>]*>\s*window._sharedData\s*=\s*((?!<script>).*)\s*;\s*</script>", response.text)
        data = json.loads(match.group(1))
        rhx_gis = data["rhx_gis"]
        csrf_token = data["config"]["csrf_token"]    
        if obj is None:
                return None
            
        data = data["entry_data"]
        for key in obj.entry_data_path:
          data=data[key]
          obj._set_data(data)
          return data
      
      
def AgentAccount():
        settings={}
        primary_key = "login"                                       ############ A   
        entry_data_path = ("ProfilePage", 0, "graphql", "user")                # C
        base_url = ""                                                          # C
        media_path = ("user", "edge_owner_to_timeline_media")                  # O
        media_query_hash = "c6809c9c025875ac6f02619eae97a80e"                  # U
        data = {"username": andivanov2019, "password": Asus2046}            ############ NT
        
        if "headers" in settings:
            settings["headers"]["X-CSRFToken"] = csrf_token
            settings["headers"]["referer"] = "https://www.instagram.com/"
        else:
            settings["headers"] = {"X-CSRFToken": csrf_token, "referer": "https://www.instagram.com/"}

        response = session.post("https://www.instagram.com/accounts/login/ajax/",data=data, **settings)
        response.raise_for_status()   
        data = response.json()
        return data

  
  def get_followers(account=None, pointer=None, count=20, settings={}, limit=50):


        update(account, settings)
        
        if pointer is None:
            variables_string = '{{"id":"{id}","first":{first}}}'
        else:
            variables_string = '{{"id":"{id}","first":{first},"after":"{after}"}}'
        followers = []

        while True:
            data = {"first": count, "id": account}
            if not pointer is None:
                data["after"] = pointer

            response = graphql_request(
                query_hash="37479f2b8209594dde7facb0d904896a",
                variables=variables_string.format(**data),
                settings=settings)


            data = response.json()["data"]["user"]["edge_followed_by"]
            edges = data["edges"]
            page_info = data["page_info"]
            followers_count = data["count"]
                
            for index in range(min(len(edges), count)):
                    node = edges[index]["node"]
                    a = node["username"]
                    id = node["id"]
                    profile_pic_url = node["profile_pic_url"]
                    is_verified = node["is_verified"]
                    full_name = node["full_name"]
                    #followers.add(a)
                    #followers.append(a)
                
                if page_info["has_next_page"]:
                    pointer = page_info["end_cursor"]
                else:
                    pointer = None
                
                if len(edges) < count and page_info["has_next_page"]:
                    count = count-len(edges)
                    variables_string = '{{"id":"{id}","first":{first},"after":"{after}"}}'
                else:
                    return followers, pointer
            

            
def graphql_request(query_hash, variables, settings={}):

        if not "params" in settings:
            settings["params"] = {"query_hash": query_hash}
        else:
            settings["params"]["query_hash"] = query_hash

        settings["params"]["variables"] = variables
        gis = "%s:%s" % (rhx_gis, variables)
        if not "headers" in settings:
            settings["headers"] = {"X-Instagram-GIS": hashlib.md5(gis.encode("utf-8")).hexdigest()}
        else:
            settings["headers"]["X-Instagram-GIS"] = hashlib.md5(gis.encode("utf-8")).hexdigest()
        settings["headers"]["X-Requested-With"] = "XMLHttpRequest"    
        response = session.get("https://www.instagram.com/graphql/query/", **settings)
        response.raise_for_status()
        return response

# %%
obj=None
if not obj is None:
  print("a")
else: print("b")
# Out:
# b

# %%
import hashlib
import json
import re
import requests



session = requests.Session()

      
def update(obj=None, settings={}):
        entry_data_path = ("ProfilePage", 0, "graphql", "user")
        primary_key = "login"
         
        base_url = ""
        query = "https://www.instagram.com/"
        if not obj is None:
            primary_key = obj
            query += base_url + primary_key
        
        response = session.get(query, **settings)
        match = re.search(r"<script[^>]*>\s*window._sharedData\s*=\s*((?!<script>).*)\s*;\s*</script>", response.text)
        #print("gggggggg", match)
        data = json.loads(match.group(1))
        #id = data["id"]
        #print("id", id)
        rhx_gis = data["rhx_gis"]
       
        csrf_token = data["config"]["csrf_token"] 
        print(csrf_token)

        if obj is None:
                return rhx_gis, csrf_token, data
            
        data = data["entry_data"]
        #print(data)
        for key in entry_data_path:
          data=data[key]
          #obj._set_data(data)
          #print("user", user)
          return rhx_gis, csrf_token, data    #, rhx_gis, csrf_token
      
      
def AgentAccount():
        rhx_gis, csrf_token, _ = update()
        settings={}
        #primary_key = "login"                                       ############ A   
        #entry_data_path = ("ProfilePage", 0, "graphql", "user")                # C
        #base_url = ""
   
        #media_path = ("user", "edge_owner_to_timeline_media")                  # O
       # media_query_hash = "c6809c9c025875ac6f02619eae97a80e"                  # U
        #data = {"username": andivanov2019, "password": Asus2046}            ############ NT
        data = {'username': 'andivanov2019', 'password': 'Asus2046'}
        #print("data:", data)
       
        if "headers" in settings:
            settings["headers"]["X-CSRFToken"] = csrf_token
            settings["headers"]["referer"] = "https://www.instagram.com/"
        else:
            settings["headers"] = {"X-CSRFToken": csrf_token, "referer": "https://www.instagram.com/"}
        response = session.post("https://www.instagram.com/accounts/login/ajax/",data=data, **settings)
        response.raise_for_status()   
        data = response.json()
        return data

print(AgentAccount())
# Out:
# D4lMu57lmJ73xVEg3frPI726w6I3sLVN
# {'authenticated': True, 'user': True, 'userId': '10397645874', 'oneTapPrompt': False, 'fr': 'ASAaisGM0OEeqVCZpoYOQO-O5A5PEaylox3Ap8RJM_g9eDNJczK5kpUDbSHeJu1NCh9t1ga1aTDRf97yU9vbaiTQA5LJd4WgYs_pBN5TJeDw1nDLwsOt7ZEzDe1A3N_7B06gnQ', 'reactivated': True, 'status': 'ok'}

# %%
_, _, data = update("valentivitell")
#d = json.loads(data)
#media_path = ("user", "edge_owner_to_timeline_media")
#data = data[media_path[-1]]
#data = data["config"]["viewer"]["id"]
#data["graphql"]["user"]["edge_owner_to_timeline_media"]["edges"]
data
#id = data["id"]
#data = data["graphql"]
# Out:
# LyORvkC611gLHic2rkqJJAKMwc8aOOIp
# [{'felix_onboarding_video_resources': {'mp4': '/static/videos/felix-onboarding/onboardingVideo.mp4/9d16838ca7f9.mp4',
#    'poster': '/static/images/felix-onboarding/onboardingVideoPoster.png/8fdba7cf2120.png'},
#   'graphql': {'user': {'biography': 'MOSCOW 👀direct📩valentivitel@mail.ru',
#     'blocked_by_viewer': False,
#     'business_address_json': None,
#     'business_category_name': None,
#     'business_email': None,
#     'business_phone_number': None,
#     'connected_fb_page': None,
#     'country_block': False,
#     'edge_felix_video_timeline': {'count': 0,
#      'edges': [],
#      'page_info': {'end_cursor': None, 'has_next_page': False}},
#     'edge_follow': {'count': 37},
#     'edge_followed_by': {'count': 1678902},
#     'edge_media_collections': {'count': 0,
#      'edges': [],
#      'page_info': {'end_cursor': None, 'has_next_page': False}},
#     'edge_mutual_followed_by': {'count': 0, 'edges': []},
#     'edge_owner_to_timeline_media': {'count': 256,
#      'edges': [{'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, shoes and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/20e882b5fa953fb8430d6443f3961a10/5CFB77E2/t51.2885-15/e35/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 64138},
#         'edge_media_preview_like': {'count': 64138},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Чем больше мне говорят гадостей про человека, тем  больше мне хочется с ним познакомиться😈(с)Красная Тапочка'}}]},
#         'edge_media_to_comment': {'count': 850},
#         'gating_info': None,
#         'id': '1966824607333496328',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BtLkI9HnDYI',
#         'taken_at_timestamp': 1548683785,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/1db2b79384ebbe618e19f0d589b1fd4e/5CF9FCA0/t51.2885-15/e35/s150x150/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/4d32fefd5013271ca37eb9d87b19c14e/5CE679EA/t51.2885-15/e35/s240x240/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f0a9da4991d3cb45428598250dfbbebb/5CF3D550/t51.2885-15/e35/s320x320/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/abc73d37b3a5a1245ca7e4fa66ed5f83/5CFF700A/t51.2885-15/e35/s480x480/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/892dca8a007bc7502cecd5b927321136/5CF50A07/t51.2885-15/sh0.08/e35/s640x640/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/892dca8a007bc7502cecd5b927321136/5CF50A07/t51.2885-15/sh0.08/e35/s640x640/50103970_2235318343462158_388265309617518605_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, standing, outdoor and water',
#         'comments_disabled': False,
#         'dimensions': {'height': 1349, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/04ef3bb494342e2a2f27b57dc1ae17ec/5CF9564C/t51.2885-15/e35/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 113435},
#         'edge_media_preview_like': {'count': 113435},
#         'edge_media_to_caption': {'edges': [{'node': {'text': '...пАтАмуШТА нечего показать кроме 🌰🤷\u200d♀️Которую, кстати, чуть не отморозила, пока шла в соседний магаз за зефирками\U0001f976'}}]},
#         'edge_media_to_comment': {'count': 1706},
#         'gating_info': None,
#         'id': '1963929000805760775',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BtBRwVZHX8H',
#         'taken_at_timestamp': 1548338602,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/459cf6b5cc48ec5d5566445f98e3f879/5CF329D7/t51.2885-15/e35/c0.134.1080.1080/s150x150/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/03619d76c0b001b9b6281f503aa6be93/5CE132D1/t51.2885-15/e35/c0.134.1080.1080/s240x240/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/b367cb1a6e32f2026afeba0ace70c43b/5CEFFFAF/t51.2885-15/e35/c0.134.1080.1080/s320x320/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/6fc86d645e8524796735ce4362663a05/5CF681E8/t51.2885-15/e35/c0.134.1080.1080/s480x480/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/6943cb473eb2bb83ef2332fd6fc23e30/5CF62040/t51.2885-15/sh0.08/e35/c0.134.1080.1080/s640x640/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/6943cb473eb2bb83ef2332fd6fc23e30/5CF62040/t51.2885-15/sh0.08/e35/c0.134.1080.1080/s640x640/47581539_2187574634840988_4868602207990607853_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 3 people, people standing, shorts and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1349, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/a1a4bd94fb5998bfc4a89369ae1a6a01/5CE98444/t51.2885-15/e35/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 105771},
#         'edge_media_preview_like': {'count': 105771},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Кто нырял в прорубь?)))Есть тут моржи?))Всех С Крещением☺️👼'}}]},
#         'edge_media_to_comment': {'count': 1799},
#         'gating_info': None,
#         'id': '1960346682669248674',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'Bs0jOvpHbCi',
#         'taken_at_timestamp': 1547911557,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f363e7aa6c8e311db7fc9b0b079f9b9e/5CFD426D/t51.2885-15/e35/c0.134.1080.1080a/s150x150/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/183c0a54b44140d18d665f13b35c4004/5CEB186B/t51.2885-15/e35/c0.134.1080.1080a/s240x240/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/ee895718c8ece9b269215059053a099c/5CF9A215/t51.2885-15/e35/c0.134.1080.1080a/s320x320/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/6ab0a70460305d307478b7bb8445f51b/5CF8D052/t51.2885-15/e35/c0.134.1080.1080a/s480x480/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/7928d3e2147a6ee8bfc8f044d34e8e66/5CF46C5D/t51.2885-15/sh0.08/e35/c0.134.1080.1080a/s640x640/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/7928d3e2147a6ee8bfc8f044d34e8e66/5CF46C5D/t51.2885-15/sh0.08/e35/c0.134.1080.1080a/s640x640/50115165_1962495820545713_9170865329645004522_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 2 people, people standing and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1351, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/0b5692a288773f0db44c45872f25779c/5CE780C4/t51.2885-15/e35/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 48384},
#         'edge_media_preview_like': {'count': 48384},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Сегодня я домашняя девочка с кружкой терафлю и банкой малинового варенья😏Покидайте фильмов хороших на вечер😇И одевайтесь теплей😘Даже от подъезда до авто🌚'}}]},
#         'edge_media_to_comment': {'count': 672},
#         'gating_info': None,
#         'id': '1958127130803908345',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BssqkA4ny75',
#         'taken_at_timestamp': 1547646965,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/d199f7659a8edeb2f1e120dd46028daa/5CF0FD3F/t51.2885-15/e35/c0.129.1028.1028/s150x150/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/e4940ef617018132ff00015d611253ee/5CF37C75/t51.2885-15/e35/c0.129.1028.1028/s240x240/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/ff990f55a75b9dbe2a9ee0f39e023ace/5CF8BFCF/t51.2885-15/e35/c0.129.1028.1028/s320x320/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/b9351a7185fbd9dc048a7ad87471de2e/5CDB3C95/t51.2885-15/e35/c0.129.1028.1028/s480x480/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/426371b2faa29e329cec6766f8b795ac/5CECC324/t51.2885-15/sh0.08/e35/c0.129.1028.1028/s640x640/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/426371b2faa29e329cec6766f8b795ac/5CECC324/t51.2885-15/sh0.08/e35/c0.129.1028.1028/s640x640/49722019_289180901784299_4501337107320785052_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphSidecar',
#         'accessibility_caption': 'Image may contain: 1 person, standing',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/209eeb434761ece9d0a4910bec4b6b42/5CEA0C54/t51.2885-15/e35/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 51693},
#         'edge_media_preview_like': {'count': 51693},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Старый Новый Год🎄 \U0001f973Всех с праздником😘💋'}}]},
#         'edge_media_to_comment': {'count': 761},
#         'gating_info': None,
#         'id': '1955872593133058522',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': None,
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'Bskp8LDnjna',
#         'taken_at_timestamp': 1547378204,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/37b2afbbbf661aba6eee6a8e20bff6b4/5CE9DDC6/t51.2885-15/e35/s150x150/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/da480a669b9b66374bc146557dfa2e74/5CE28673/t51.2885-15/e35/s240x240/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/aac5aadde53e6fa6b8aa5771d3e214ef/5CF28FCB/t51.2885-15/e35/s320x320/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/b89c48afa4543743d9d2f6c495e92845/5CFE5697/t51.2885-15/e35/s480x480/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f12009778efa9cd3b609609e4a3a1e5b/5CF42627/t51.2885-15/sh0.08/e35/s640x640/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/f12009778efa9cd3b609609e4a3a1e5b/5CF42627/t51.2885-15/sh0.08/e35/s640x640/47690550_544159949431806_250097195167894852_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, standing',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/d390e3069b74730437c8f91d50ad00dc/5CF33421/t51.2885-15/e35/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 42194},
#         'edge_media_preview_like': {'count': 42194},
#         'edge_media_to_caption': {'edges': [{'node': {'text': '💋'}}]},
#         'edge_media_to_comment': {'count': 519},
#         'gating_info': None,
#         'id': '1955156907901455101',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsiHNlPngr9',
#         'taken_at_timestamp': 1547292887,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/4fb25ec1e5e62e3d29867f717429700c/5CF84863/t51.2885-15/e35/s150x150/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/36e839ec33f45c1f33991ce013f5badd/5CEB2929/t51.2885-15/e35/s240x240/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/a951fc55fa0b83fadce5a9e0189cdcdd/5CF10793/t51.2885-15/e35/s320x320/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f2aa70d8b5643ca1fe13cf691f661b52/5CE9A0C9/t51.2885-15/e35/s480x480/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/d8b3480845b9413ac3793eed6c7fefe2/5CF113C4/t51.2885-15/sh0.08/e35/s640x640/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/d8b3480845b9413ac3793eed6c7fefe2/5CF113C4/t51.2885-15/sh0.08/e35/s640x640/49641305_395087891058064_2423156184829751913_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, sky, shoes and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/14228fe83d0ff8da8d907502ede29f1d/5CF20CE1/t51.2885-15/e35/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 62637},
#         'edge_media_preview_like': {'count': 62637},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Какой знак зодиака самый темпераментный, как вы думаете?😜'}}]},
#         'edge_media_to_comment': {'count': 1035},
#         'gating_info': None,
#         'id': '1953779159727587743',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '6889842',
#          'name': 'Paris, France',
#          'slug': 'paris-france'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsdN8tRH8Gf',
#         'taken_at_timestamp': 1547128647,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/ce5785181cdc0c317bdeec08612cd51a/5CFDA0A3/t51.2885-15/e35/s150x150/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/27b94227d917c177fd7b65fd068b2758/5CDAE3E9/t51.2885-15/e35/s240x240/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/2cd21e6ed46c00af9bce5219ed5ee7cd/5CE97653/t51.2885-15/e35/s320x320/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/d33d61f9b12788c9e3c2c2b1df11fb49/5CE8B609/t51.2885-15/e35/s480x480/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/5f8fb333d743c2b6d5e231cca21f1c53/5CEF0904/t51.2885-15/sh0.08/e35/s640x640/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/5f8fb333d743c2b6d5e231cca21f1c53/5CEF0904/t51.2885-15/sh0.08/e35/s640x640/47692261_633972690355852_4333042468903099670_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, standing and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1350, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/ed9db2dfe1d0c66590c0c1c86fdae586/5CFC03D9/t51.2885-15/e35/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 39643},
#         'edge_media_preview_like': {'count': 39643},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Эта лучше😁Передумала\U0001f92a'}}]},
#         'edge_media_to_comment': {'count': 395},
#         'gating_info': None,
#         'id': '1952265966504903564',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '6889842',
#          'name': 'Paris, France',
#          'slug': 'paris-france'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsX142QnAOM',
#         'taken_at_timestamp': 1546948260,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/bdc1ba02bbc447c72a055c1e4dd07c5d/5CF79F24/t51.2885-15/e35/c0.114.909.909/s150x150/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/3142010f82af3cd35cca89d95a494469/5CE3E06E/t51.2885-15/e35/c0.114.909.909/s240x240/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/e94d1484a7d7bc4ced5c687af58b657d/5CF9B2D4/t51.2885-15/e35/c0.114.909.909/s320x320/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/3889242a45432838919d9f650c9ff197/5CFE418E/t51.2885-15/e35/c0.114.909.909/s480x480/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/fc27ae08fde2387c6ffbcf3d7530c241/5CF8282E/t51.2885-15/sh0.08/e35/c0.114.909.909/s640x640/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/fc27ae08fde2387c6ffbcf3d7530c241/5CF8282E/t51.2885-15/sh0.08/e35/c0.114.909.909/s640x640/47582641_107064623603029_4159311745993485107_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, closeup',
#         'comments_disabled': False,
#         'dimensions': {'height': 1349, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/6d766c3181bc263f4d2bbfa6937857e4/5CE5DCFB/t51.2885-15/e35/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 74565},
#         'edge_media_preview_like': {'count': 74565},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'В каком ухе звенит?😁'}}]},
#         'edge_media_to_comment': {'count': 1249},
#         'gating_info': None,
#         'id': '1950784314121454482',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsSk_98nQOS',
#         'taken_at_timestamp': 1546771633,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/0b42fbcaaa0b115320250f5376fab107/5CE7AC21/t51.2885-15/e35/c0.133.1066.1066/s150x150/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/a9280bed998266501bb30d7279527b16/5CE1216B/t51.2885-15/e35/c0.133.1066.1066/s240x240/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/2785784be834415822ca854660720f53/5CE6D3D1/t51.2885-15/e35/c0.133.1066.1066/s320x320/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/3b43873827869dccf9e34005eda69e8e/5CE07C8B/t51.2885-15/e35/c0.133.1066.1066/s480x480/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f366b5c1e7c9c32c588c147fe14bf28d/5CF2D13A/t51.2885-15/sh0.08/e35/c0.133.1066.1066/s640x640/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/f366b5c1e7c9c32c588c147fe14bf28d/5CF2D13A/t51.2885-15/sh0.08/e35/c0.133.1066.1066/s640x640/47582979_284587508925880_3504868262721009610_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, sitting',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/f437f67e5d2413c50fb4ffffab6df3aa/5CE9D133/t51.2885-15/e35/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 30272},
#         'edge_media_preview_like': {'count': 30272},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Спасибо, что живой\U0001f92aКто-где отметил?😁Как после праздников перестать вставать в 15 часов?👀🤦\u200d♀️'}}]},
#         'edge_media_to_comment': {'count': 313},
#         'gating_info': None,
#         'id': '1950092980733789029',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '17326249',
#          'name': 'Moscow, Russia',
#          'slug': 'moscow-russia'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsQHzvjnsNl',
#         'taken_at_timestamp': 1546689220,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/3fc23e6a979ca4e9798c289c7cec1488/5CF93871/t51.2885-15/e35/s150x150/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/8b4d0cab6bb5050b512e80ea7103cee9/5CEEA13B/t51.2885-15/e35/s240x240/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/c5bc6ee16a36479b19a929a8be1f724d/5CF4E281/t51.2885-15/e35/s320x320/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/59d68aebe5cbd76d6df826d2515ccf45/5CE1FFDB/t51.2885-15/e35/s480x480/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/e383c115b67789b591fa16aee4fa1022/5CE3E9D6/t51.2885-15/sh0.08/e35/s640x640/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/e383c115b67789b591fa16aee4fa1022/5CE3E9D6/t51.2885-15/sh0.08/e35/s640x640/46607239_973000619577426_1082734778775776975_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 2 people, people standing and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1080, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/a41449bebf029ea49b66bf317d3dd82b/5CE2E800/t51.2885-15/e35/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 43692},
#         'edge_media_preview_like': {'count': 43692},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Стиль бомжа в кроссах и куртке оверсайз я больше люблю, но девочкой иногда быть тоже нужно☝️😁Хотя бы на фото в инсте🌚'}}]},
#         'edge_media_to_comment': {'count': 630},
#         'gating_info': None,
#         'id': '1948732916534068163',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '6889842',
#          'name': 'Paris, France',
#          'slug': 'paris-france'},
#         'media_preview': '...',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsLSkNEH8PD',
#         'taken_at_timestamp': 1546527088,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/e07345302413399a1bf801388f1d891c/5CE49742/t51.2885-15/e35/s150x150/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/b464af1a6850af941e48e496d67bb137/5CF01508/t51.2885-15/e35/s240x240/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/12b998c10b09fed581451fe1b9a18b1c/5CEAFEB2/t51.2885-15/e35/s320x320/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/319d3e99e6debc72e818bad6c30ea142/5CDEA3E8/t51.2885-15/e35/s480x480/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/f1d0231a1de3ef85597db5d2af0aa668/5CF82CE5/t51.2885-15/sh0.08/e35/s640x640/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/f1d0231a1de3ef85597db5d2af0aa668/5CF82CE5/t51.2885-15/sh0.08/e35/s640x640/47581589_697602350641317_4336545859554036027_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}},
#       {'node': {'__typename': 'GraphImage',
#         'accessibility_caption': 'Image may contain: 1 person, standing and outdoor',
#         'comments_disabled': False,
#         'dimensions': {'height': 1350, 'width': 1080},
#         'display_url': 'https://scontent-mia3-1.cdninstagram.com/vp/a566dcd2f379e21ac2ce3a9b9f6c6df8/5CDB96ED/t51.2885-15/e35/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#         'edge_liked_by': {'count': 60851},
#         'edge_media_preview_like': {'count': 60851},
#         'edge_media_to_caption': {'edges': [{'node': {'text': 'Всех с годом желтой земляной свиньи!!!\U0001f973\U0001f973\U0001f973Хрю)🐷🐖P.S. Я скрестила пальцы на ногах, что бы цыгане меня не украли в этом наряде😁🤞'}}]},
#         'edge_media_to_comment': {'count': 849},
#         'gating_info': None,
#         'id': '1947182142800709819',
#         'is_video': False,
#         'location': {'has_public_page': True,
#          'id': '6889842',
#          'name': 'Paris, France',
#          'slug': 'paris-france'},
#         'media_preview': '',
#         'owner': {'id': '1090074015', 'username': 'valentivitell'},
#         'shortcode': 'BsFx9eensi7',
#         'taken_at_timestamp': 1546342221,
#         'thumbnail_resources': [{'config_height': 150,
#           'config_width': 150,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/2ad097317c563fdb1c365d76a49b0ec0/5CF771E2/t51.2885-15/e35/c0.135.1080.1080/s150x150/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 240,
#           'config_width': 240,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/1713e779c584704458a4c5c0a64b5de6/5CFCD0E4/t51.2885-15/e35/c0.135.1080.1080/s240x240/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 320,
#           'config_width': 320,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/c4c9aa3c45ceebb7419506e8911f2b65/5CEBD19A/t51.2885-15/e35/c0.135.1080.1080/s320x320/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 480,
#           'config_width': 480,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/55a1c9bca56fb9fd4122a86a9bd2b374/5CE43FDD/t51.2885-15/e35/c0.135.1080.1080/s480x480/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'},
#          {'config_height': 640,
#           'config_width': 640,
#           'src': 'https://scontent-mia3-1.cdninstagram.com/vp/c02e1b0dbec24f44ea9bb45059ce9be6/5CE7BB75/t51.2885-15/sh0.08/e35/c0.135.1080.1080/s640x640/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}],
#         'thumbnail_src': 'https://scontent-mia3-1.cdninstagram.com/vp/c02e1b0dbec24f44ea9bb45059ce9be6/5CE7BB75/t51.2885-15/sh0.08/e35/c0.135.1080.1080/s640x640/47692382_1852798641514658_8084608618368653864_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com'}}],
#      'page_info': {'end_cursor': 'QVFBaFFIcDFTWkNTcW05VFdiaXFkR21jYjVkOGtwdlZNb3pYVjUyZmFtMEU4WW1wZ2M4S0hxREtFNS03OXR2MjZsV0lESlRxR1FHcko0cGQ5WHk4NmYwMw==',
#       'has_next_page': True}},
#     'edge_saved_media': {'count': 0,
#      'edges': [],
#      'page_info': {'end_cursor': None, 'has_next_page': False}},
#     'external_url': None,
#     'external_url_linkshimmed': None,
#     'followed_by_viewer': False,
#     'follows_viewer': False,
#     'full_name': 'Vi',
#     'has_blocked_viewer': False,
#     'has_channel': False,
#     'has_requested_viewer': False,
#     'highlight_reel_count': 7,
#     'id': '1090074015',
#     'is_business_account': False,
#     'is_joined_recently': False,
#     'is_private': False,
#     'is_verified': True,
#     'profile_pic_url': 'https://scontent-mia3-1.cdninstagram.com/vp/d43bb8fff89d2945726ea59201068617/5CDBA00E/t51.2885-19/s150x150/38096761_649269845446876_4161954052923457536_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#     'profile_pic_url_hd': 'https://scontent-mia3-1.cdninstagram.com/vp/79e286d9801f44d05ba2b9845f9c8024/5CEE08FE/t51.2885-19/s320x320/38096761_649269845446876_4161954052923457536_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com',
#     'requested_by_viewer': False,
#     'username': 'valentivitell'}},
#   'logging_page_id': 'profilePage_1090074015',
#   'show_suggested_profiles': False}]

# %%
import hashlib
import json
import re
import requests



session = requests.Session()

      
def update(obj=None, settings={}):
        entry_data_path = ("ProfilePage", 0, "graphql", "user")
        primary_key = "login"
        src_adress = [] 
        base_url = ""
        query = "https://www.instagram.com/"
        if not obj is None:
            primary_key = obj
            query += base_url + primary_key
        
        response = session.get(query, **settings)
        match = re.search(r"<script[^>]*>\s*window._sharedData\s*=\s*((?!<script>).*)\s*;\s*</script>", response.text)
        data = json.loads(match.group(1))
        rhx_gis = data["rhx_gis"]
        csrf_token = data["config"]["csrf_token"]
        idx = data["entry_data"]["ProfilePage"][0]["graphql"]["user"]["id"]
        for number in range(len(data["entry_data"]["ProfilePage"][0]["graphql"]["user"]["edge_owner_to_timeline_media"]["edges"])):
	          src_adress.append(data["entry_data"]["ProfilePage"][0]["graphql"]["user"]["edge_owner_to_timeline_media"]["edges"][number]["node"]["thumbnail_resources"][4]["src"])
        if data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['page_info']['has_next_page']:                 
            pointer = data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['page_info']['end_cursor']
        else:
            pointer = None

        return data, rhx_gis, csrf_token, pointer, src_adress, idx

      
      
      
def photo(account, count=12, settings={}, limit=50):
        _, rhx_gis, _, pointer, _, idx = update(account)

        #variables_string = '{{"fetch_media_item_count":{first},"fetch_media_item_cursor":"{after}",\
          #  "fetch_comment_count":4,"fetch_like":10,"has_stories":false}}'
        if pointer is None:
            variables_string = '{{"id":"{name_value}","first":{first}}}'
        else:
            variables_string = '{{"id":"{name_value}","first":{first},"after":"{after}"}}'
        feed = []

        while True:
            data = {"first": count, "name_value": idx}
            if not pointer is None:
                data["after"] = pointer

            response = graphql_request(
                query_hash="f2405b236d85e8296cf30347c9f08c2a",
                variables=variables_string.format(**data),
                settings=settings)

            
            data = response.json()         #["data"]["user"]["edge_followed_by"]
        return data
'''
            edges = data["edges"]
            page_info = data["page_info"]
            length = len(edges)

            
            
            for index in range(min(length, count)):
                    node = edges[index]["node"]
                    url = node["thumbnail_resources"]        #["src"]
                    if not "shortcode" in node:
                        length -= 1
                        continue
                    m = node["thumbnail_resources"][0]["src"]
                    #m._set_data(node)
                    feed.append(m)
                    #print("node", node)
                
            if page_info["has_next_page"]:
                    
                    pointer = page_info["end_cursor"]
            else:
                    pointer = None
                
            if length < count and page_info["has_next_page"]:
                    count = count-length
            else:
                    return feed, pointer
'''

def graphql_request(query_hash, variables, settings={}, rhx_gis=None):

        if not "params" in settings:
            settings["params"] = {"query_hash": query_hash}
        else:
            settings["params"]["query_hash"] = query_hash

        settings["params"]["variables"] = variables
        gis = "%s:%s" % (rhx_gis, variables)
        if not "headers" in settings:
            settings["headers"] = {"X-Instagram-GIS": hashlib.md5(gis.encode("utf-8")).hexdigest()}
        else:
            settings["headers"]["X-Instagram-GIS"] = hashlib.md5(gis.encode("utf-8")).hexdigest()
        settings["headers"]["X-Requested-With"] = "XMLHttpRequest" 
        print(settings)
        response = session.get("https://www.instagram.com/graphql/query/", **settings)
        response.raise_for_status()
        return response

# %%
data = photo("valentivitell")
print(data)
# Out:
# {'params': {'query_hash': 'f2405b236d85e8296cf30347c9f08c2a', 'variables': '{"id":"1090074015","first":12,"after":"QVFETWpTcUItMy1WbWI0aHdWT0NxMWhYVVdhSHNEWDNzb0cxeXE4Vi1tSmdMbS1LNnphRnZSWXRpSk1DZk1RRy1YWUNvSXdkNkpFVXF5bmczbnRDNEdhNA=="}'}, 'headers': {'X-Instagram-GIS': 'c72a58e2b84b3db0d6e7bb9dff5658d0', 'X-Requested-With': 'XMLHttpRequest'}}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-0d98022222cf> in <module>()
#       1
# ----> 2 data = photo("valentivitell")
#       3 print(data)
#
# <ipython-input-3-0439211d7845> in photo(account, count, settings, limit)
#      56                 query_hash="f2405b236d85e8296cf30347c9f08c2a",
#      57                 variables=variables_string.format(**data),
# ---> 58                 settings=settings)
#      59
#      60
#
# <ipython-input-3-0439211d7845> in graphql_request(query_hash, variables, settings, rhx_gis)
#     107         print(settings)
#     108         response = session.get("https://www.instagram.com/graphql/query/", **settings)
# --> 109         response.raise_for_status()
#     110         return response
#     111
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in raise_for_status(self)
#     933
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#     937     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.instagram.com/graphql/query/?query_hash=f2405b236d85e8296cf30347c9f08c2a&variables=%7B%22id%22%3A%221090074015%22%2C%22first%22%3A12%2C%22after%22%3A%22QVFETWpTcUItMy1WbWI0aHdWT0NxMWhYVVdhSHNEWDNzb0cxeXE4Vi1tSmdMbS1LNnphRnZSWXRpSk1DZk1RRy1YWUNvSXdkNkpFVXF5bmczbnRDNEdhNA%3D%3D%22%7D

# %%
#short_adress = []
# shortcode - code picture
#for number in range(len(json_dict['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges'])):
#	short_adress.append(json_dict['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges'][number]['node']['shortcode'])
#json_dict['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['page_info'][end_cursor]['has_next_page']

def photo(account, pointer=None, count=100, settings={}, limit=50):
        rhx_gis, _, _ = update(account)

        #variables_string = '{{"fetch_media_item_count":{first},"fetch_media_item_cursor":"{after}",\
          #  "fetch_comment_count":4,"fetch_like":10,"has_stories":false}}'
        if pointer is None:
            variables_string = '{{"id":"{name_value}","first":{first}}}'
        else:
            variables_string = '{{"id":"{name_value}","first":{first},"after":"{after}"}}'
        feed = []

        while True:
            data = {"first": count, "name_value": 1090074015}
            if not pointer is None:
                data["after"] = pointer

            response = graphql_request(
                query_hash="37479f2b8209594dde7facb0d904896a",
                variables=variables_string.format(**data),
                settings=settings)

            
            data = response.json()         #["data"]["user"]["edge_followed_by"]

            edges = data["edges"]
            page_info = data["page_info"]
            length = len(edges)

            
            
            for index in range(min(length, count)):
                    node = edges[index]["node"]
                    url = node["thumbnail_resources"]        #["src"]
                    if not "shortcode" in node:
                        length -= 1
                        continue
                    m = node["thumbnail_resources"][0]["src"]
                    #m._set_data(node)
                    feed.append(m)
                    #print("node", node)
                
            if page_info["has_next_page"]:
                    
                    pointer = page_info["end_cursor"]
            else:
                    pointer = None
                
            if length < count and page_info["has_next_page"]:
                    count = count-length
            else:
                    return feed, pointer
            
def graphql_request(query_hash, variables, settings={}, rhx_gis=None):

        if not "params" in settings:
            settings["params"] = {"query_hash": query_hash}
        else:
            settings["params"]["query_hash"] = query_hash

        settings["params"]["variables"] = variables
        gis = "%s:%s" % (rhx_gis, variables)
        if not "headers" in settings:
            settings["headers"] = {"X-Instagram-GIS": hashlib.md5(gis.encode("utf-8")).hexdigest()}
        else:
            settings["headers"]["X-Instagram-GIS"] = hashlib.md5(gis.encode("utf-8")).hexdigest()
        settings["headers"]["X-Requested-With"] = "XMLHttpRequest" 
        print(settings)
        response = session.get("https://www.instagram.com/graphql/query/", **settings)
        response.raise_for_status()
        return response

# %%
ai = []
a, b = photo("valentivitell")
ai.extend(a)
print(len(a))

for i in range(100):
  a, b = photo("valentivitell", pointer=b)
  ai.extend(a)
  print(ai)
# Out:
# FgP01YZtfT5VCVtNpi8ZAUfrFkkmSvoa
# {'params': {'query_hash': '37479f2b8209594dde7facb0d904896a', 'variables': '{"id":"1090074015","first":100}'}, 'headers': {'X-Instagram-GIS': '0fff0206712eea1efbdfecb0ea215a9b', 'X-Requested-With': 'XMLHttpRequest'}}
#
# {'data': {'user': {'edge_followed_by': {'count': 1675784, 'page_info': {'has_next_page': True, 'end_cursor': 'QVFCcU1fVTRTbmh4akNzMlluQkFsOEpKMzR6Yi1HdndFMGpFYjlnMTdqM3VIeTQzM1lIbFJOMUp4MHdyRTZCOHZ6UWlwX1l5bmVFQWhkRmlRa29rMVVCcQ=='}, 'edges': [{'node': {'id': '5663021408', 'username': 'andyraj76', 'full_name': 'Ayudh', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/d9801fa4fc78e07b9210aaaed6acf16e/5CEECDEB/t51.2885-19/s150x150/40752671_299175030672429_394309711811313664_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '10591383194', 'username': 'somaya1111akter', 'full_name': 'md maruf hasan', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/18f217c4414d618a8480d99153810dca/5CF201F5/t51.2885-19/s150x150/50636920_205039730371002_8470509440037027840_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '3578985580', 'username': 'knowl3dge_fx_trading', 'full_name': 'ERIC MANZINI 😒🖕🏼', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/fe1b3fca38076bbcc4c37a0d030b219c/5CC6734A/t51.2885-19/s150x150/45634498_2182942905278479_7434956468073267200_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '7710066755', 'username': 'talisonolliveira', 'full_name': 'Tálison Olliveira', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/1b86200a502321c30328556210e37b33/5CE5C40A/t51.2885-19/s150x150/41656315_292118738274638_9125791505171087360_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '9951605426', 'username': 'temptationloveshop', 'full_name': 'Temptation Love', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/1a491cd43134fc49b41cd076fa3cbb9e/5CC60BF3/t51.2885-19/s150x150/47448282_2104605693183802_663964813969326080_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '9266487771', 'username': 'fhdhsnshnyn', 'full_name': 'فهد حسن شنين', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/05e685f6236fb22d4d59479e4dd074b9/5CEE7891/t51.2885-19/s150x150/46169222_208816789994064_5033704106158456832_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '8434652550', 'username': 'jasonjohnsham1974', 'full_name': 'Shamotions CC', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/f8a303a3a5dc35c25758718a702bafcb/5CE71348/t51.2885-19/s150x150/39287177_290440344873496_1605218300025896960_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '5348669382', 'username': 'serseri35___', 'full_name': 'serseri35', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/52445f2002794f8bdd409948bf103a13/5CF5E623/t51.2885-19/s150x150/40379276_247051039334763_3196318617348079616_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '3901632481', 'username': 'buldunk', 'full_name': 'buldunk', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/0ca6c60f05e497ed6c7dc0fcd8f188a4/5CE7044B/t51.2885-19/s150x150/29715321_591481464560844_4808511424571637760_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com', 'is_verified': False, 'followed_by_viewer': False, 'requested_by_viewer': False}}, {'node': {'id': '10628110559', 'username': 'marciarodrigues3556', 'full_name': 'marcia Rodrigues', 'profile_pic_url': 'https://scontent-sea1-1.cdninstagram.com/vp/7350398bd4f522bf5073cc84c99483fc/5CEEFA28/t51.2885-19/s150x150/50 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-7558ee025fd1> in <module>()
#       1 ai = []
# ----> 2 a, b = photo("valentivitell")
#       3 ai.extend(a)
#       4 print(len(a))
#       5
#
# <ipython-input-74-a3b7d7eeb996> in photo(account, pointer, count, settings, limit)
#      24             data = response.json()         #["data"]["user"]["edge_followed_by"]
#      25             print(data)
# ---> 26             edges = data["edges"]
#      27             page_info = data["page_info"]
#      28             length = len(edges)
#
# KeyError: 'edges'

# %%
def graphql_request(query_hash, variables, settings={}, rhx_gis=None):

        if not "params" in settings:
            settings["params"] = {"query_hash": query_hash}
        else:
            settings["params"]["query_hash"] = query_hash

        settings["params"]["variables"] = variables
        gis = "%s:%s" % (rhx_gis, variables)
        if not "headers" in settings:
            settings["headers"] = {"X-Instagram-GIS": hashlib.md5(gis.encode("utf-8")).hexdigest()}
        else:
            settings["headers"]["X-Instagram-GIS"] = hashlib.md5(gis.encode("utf-8")).hexdigest()
        settings["headers"]["X-Requested-With"] = "XMLHttpRequest" 
        print(settings)
        response = session.get("https://www.instagram.com/graphql/query/", **settings)
        response.raise_for_status()
        return response


def feed(account, pointer=None, count=100, settings={}, limit=50):
        rhx_gis, _, _ = update(account)

        variables_string = '{{"fetch_media_item_count":{first},"fetch_media_item_cursor":"{after}",\
            "fetch_comment_count":4,"fetch_like":10,"has_stories":false}}'
        feed = []

        while True:
            response = graphql_request(
                rhx_gis=rhx_gis,
                query_hash="485c25657308f08317c1e4b967356828",
                variables=variables_string.format(after=pointer, first=min(limit, count)) if pointer else "{}",
                settings=settings,
            )

            
            data = response.json()["data"]["user"]["edge_web_feed_timeline"]
            edges = data["edges"]
            page_info = data["page_info"]
            length = len(edges)
                
            for index in range(min(length, count)):
                    node = edges[index]["node"]
                    if not "shortcode" in node:
                        length -= 1
                        continue
                    m = node["shortcode"]
                    #m._set_data(node)
                    feed.append(m)
                    print("node", node)
                
            if page_info["has_next_page"]:
                    
                    pointer = page_info["end_cursor"]
            else:
                    pointer = None
                
            if length < count and page_info["has_next_page"]:
                    count = count-length
            else:
                    return feed, pointer

# %%
# Out:
# n9EkuMRUBfEEMFxnraqWJnuSVWSiDgQO
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-7558ee025fd1> in <module>()
#       1 ai = []
# ----> 2 a, b = photo("valentivitell")
#       3 ai.extend(a)
#       4 print(len(a))
#       5
#
# <ipython-input-90-1331f39846be> in photo(account, pointer, count, settings, limit)
#      27             for index in range(min(length, count)):
#      28                     node = edges[index]["node"]
# ---> 29                     url = node["thumbnail_resources"]        #["src"]
#      30                     if not "shortcode" in node:
#      31                         length -= 1
#
# KeyError: 'thumbnail_resources'

# %%
ai

# %%
 def get_followers(account=None, pointer=None, count=20, settings={}, limit=50):


        update(account, settings)
        
        if pointer is None:
            variables_string = '{{"id":"{id}","first":{first}}}'
        else:
            variables_string = '{{"id":"{id}","first":{first},"after":"{after}"}}'
        followers = []

        while True:
            data = {"first": count, "id": account}
            if not pointer is None:
                data["after"] = pointer

            response = graphql_request(
                query_hash="37479f2b8209594dde7facb0d904896a",
                variables=variables_string.format(**data),
                settings=settings)


            data = response.json()["data"]["user"]["edge_followed_by"]
            edges = data["edges"]
            page_info = data["page_info"]
            followers_count = data["count"]
                
            for index in range(min(len(edges), count)):
                    node = edges[index]["node"]
                    a = node["username"]
                    id = node["id"]
                    profile_pic_url = node["profile_pic_url"]
                    is_verified = node["is_verified"]
                    full_name = node["full_name"]
                    #followers.add(a)
                    #followers.append(a)
                
                if page_info["has_next_page"]:
                    pointer = page_info["end_cursor"]
                else:
                    pointer = None
                
                if len(edges) < count and page_info["has_next_page"]:
                    count = count-len(edges)
                    variables_string = '{{"id":"{id}","first":{first},"after":"{after}"}}'
                else:
                    return followers, pointer

# %%
def get_media(obj, pointer=None, count=12, settings={}, limit=50):  
        primary_key = "code"
        entry_data_path = ("PostPage", 0, "graphql", "shortcode_media")
        media_path = ("user", "edge_owner_to_timeline_media")
        base_url = "p/"
        data = update(obj, settings)
        variables_string = '{{"{name}":"{name_value}","first":{first},"after":"{after}"}}'
        medias = []
        
        if pointer is None:
                data = data[media_path[-1]]
                
                page_info = data["page_info"]
                edges = data["edges"]
                
                for index in range(min(len(edges), count)):
                    node = edges[index]["node"]
                    m = node["shortcode"]
                    #m._set_data(node)
                    #if isinstance(obj, Account):
                    likes_count = node["edge_media_preview_like"]["count"]
                        #m.owner = obj
                   # else:
                       # m.likes_count = node["edge_liked_by"]
                    
                    #obj.media.add(m)
                    medias.append(m)
                
                if page_info["has_next_page"]:
                    pointer = page_info["end_cursor"]
                
                if len(edges) < count and page_info["has_next_page"]:
                    count = count - len(edges)
                else:
                    return medias, pointer
                

        while True:
            data = {"after": pointer, "first": min(limit, count)}
            #if isinstance(obj, Tag):
            #    data["name"] = "tag_name"
            #    data["name_value"] = name
            #else:
            data["name"] = "id"
            data["name_value"] = id

            response = graphql_request(query_hash=media_query_hash, variables=variables_string.format(**data),settings=settings)
            data = response.json()["data"]
            for key in media_path:
                    data = data[key]
            page_info = data["page_info"]
            edges = data["edges"]
                
            for index in range(min(len(edges), count)):
                    node = edges[index]["node"]
                    m = Media(node["shortcode"])
                    #m._set_data(node)
                    #if isinstance(obj, Account):
                    likes_count = node["edge_media_preview_like"]["count"]
                      #  m.owner = obj
                    #else:
                      #  m.likes_count = node["edge_liked_by"]
                   # obj.media.add(m)
                    medias.append(m)
                
            if page_info["has_next_page"]:
                    pointer = page_info["end_cursor"]
            else:
                    pointer = None
                
            if len(edges) < count and page_info["has_next_page"]:
                    count = count - len(edges)
            else:
                    return medias, pointer

# %%
get_media(valentivitell)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-487a32082868> in <module>()
# ----> 1 get_media(valentivitell)
#
# NameError: name 'valentivitell' is not defined

# %%
#data1 = {}
#data1 = {'username': 'andivanov2019', 'password': 'Asus2046'}  
#dict = "d1"
d1 = dict(shorts='dictq', long='dictionary')
d1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0c96cb5e2f1e> in <module>()
# ----> 1 d1 = dict(shorts='dictq', long='dictionary')
#       2 d1
#
# TypeError: 'str' object is not callable

# %%
f=6
v = {'dict': f, 'dictionary': 2}
v
# Out:
# {'dict': 6, 'dictionary': 2}
